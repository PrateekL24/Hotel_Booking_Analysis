# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loding Dataset

# %%
hotel_data = pd.read_csv(r"C:\Users\lapal\OneDrive\Desktop\hotel_bookings 2.csv")

# %%
hotel_data.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %% [markdown]
# ## EDA and Cleaning

# %%
hotel_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_data.shape
# Out:
# (119390, 32)

# %%
hotel_data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Now I want to change the reservation_status_date datatype to date

# %%
hotel_data['reservation_status_date'] = pd.to_datetime(hotel_data['reservation_status_date'])

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_data.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in hotel_data.describe(include = 'object').columns:
    print(col)
    print(hotel_data[col].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %% [markdown]
# As in the dataset we can see in Hotel there are tow value
# Restor and City hotel
#
# In the market segment TA means Travel agent and TO means Tour operator
#
# In reservation No show mean the customer nither cancel and nor check in

# %% [markdown]
# Checking Missing valuse

# %%
hotel_data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# In the dataset agent column is no use and company data is having lots of null valuse that we can't handle so we remove the columns

# %%
hotel_data.drop(['company', 'agent'], axis = 1, inplace = True)
hotel_data.dropna(inplace = True)

# %%
hotel_data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
hotel_data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
hotel_data['adr'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now in adr(average daily rate) there is a outlier
# To remove the outlier

# %%
hotel_data = hotel_data[hotel_data['adr']<5000]

# %%
hotel_data['adr'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
hotel_data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## Data Analysis And Visualizations

# %%
cancelled_perc = hotel_data['is_canceled'].value_counts(normalize = True)*100
print(cancelled_perc)
# Out:
# 0    62.865337
# 1    37.134663
# Name: is_canceled, dtype: float64

# %% [markdown]
# We can see that 37% is cancelation

# %%
plt.figure(figsize = (5,4))
plt.title('Reservation status count')
plt.bar(['Not canceled','Canceled'],hotel_data['is_canceled'].value_counts(), edgecolor = 'k', width = 0.7)
plt.show()

# %% [markdown]
# In the Bar graph we can see that almost more than  50 % is cancel

# %%
plt.figure(figsize = (8,4))
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled',data = hotel_data, palette = 'Blues')
legend_labels,_ = ax1. get_legend_handles_lables()
ax1.legend(bbox_to_anchor(1,1))
plt.title('Reservation status in diffrent hotels', size = 20)
plt.xlable('hotel')
plt.ylable('number of reservations')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13716\2183202390.py in <module>
#       1 plt.figure(figsize = (8,4))
#       2 ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled',data = hotel_data, palette = 'Blues')
# ----> 3 legend_labels,_ = ax1. get_legend_handles_lables()
#       4 ax1.legend(bbox_to_anchor(1,1))
#       5 plt.title('Reservation status in diffrent hotels', size = 20)
#
# AttributeError: 'AxesSubplot' object has no attribute 'get_legend_handles_lables'

# %%
resort_hotel = hotel_data[hotel_data['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)*100
# Out:
# 0    72.024952
# 1    27.975048
# Name: is_canceled, dtype: float64

# %% [markdown]
# In Resort Hotel aprox 28% is cancellation is there

# %%
city_hotel = hotel_data[hotel_data['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)*100
# Out:
# 0    58.291825
# 1    41.708175
# Name: is_canceled, dtype: float64

# %% [markdown]
# In the City hotels we can see there is very large cancellation rate is aprox 42 %

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize= (20,8))
plt.title('Avgrage Daily Rate in city and resort hotel', fontsize = 30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label = 'Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# In city hotel prices are low in some days as compared to resort hotel
# Days are holiday and weekends

# %%
hotel_data['month'] = hotel_data['reservation_status_date'].dt.month
plt.figure(figsize = (16,8))
ax1 = sns.countplot(x= 'month' ,hue= 'is_canceled', data = hotel_data, palette = 'bright')
legend_labels,_ = ax1. get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status per month', size = 20)
plt.xlable('month')
plt.ylable('number of reservation')
plt.legend(['not canceled','canceled'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13716\2367847330.py in <module>
#       5 ax1.legend(bbox_to_anchor=(1,1))
#       6 plt.title('Reservation status per month', size = 20)
# ----> 7 plt.xlable('month')
#       8 plt.ylable('number of reservation')
#       9 plt.legend(['not canceled','canceled'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# Blue bars are not canceled and orange showes canceled
# In this graph we can see that
# In the month of august the cancellation rate is lowest and reservation is highest
# And in January there is highest cancelation rate and lowest reservation

# %%
plt.figure(figsize = (15,8))
plt.title('ADR per month', fontsize = 30)
sns.barplot('month', 'adr', data = hotel_data[hotel_data['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %% [markdown]
# In august the adr is lowest and in january the adr is higest
# So we can conclude that if the rates are higher so there are chances of clancelation

# %%
cancelled_data = hotel_data[hotel_data['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize = (8,8))
plt.title = ('Top 10 countries with reservation cancelled')
plt.pie(top_10_country, autopct = '%.2f', labels = top_10_country.index)
plt.show()

# %% [markdown]
# As we can see 70% cancelation rates are from Portugal
# then 6.25% is United Kingdom and then 5.54 for Spain and so on.

# %% [markdown]
# We can suggest Portugal to decrese there price and improve there facilites. And they can run campaigns and promotional advertisement

# %%
hotel_data['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
hotel_data['market_segment'].value_counts(normalize  = True)*100
# Out:
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: market_segment, dtype: float64

# %% [markdown]
# The majorty of clients are coming from Online Travel Agents

# %%
cancelled_data['market_segment'].value_counts(normalize  = True)*100
# Out:
# Online TA        46.969560
# Groups           27.398532
# Offline TA/TO    18.746603
# Direct            4.348614
# Corporate         2.215075
# Complementary     0.203841
# Aviation          0.117775
# Name: market_segment, dtype: float64

# %% [markdown]
# And most of the cancelaton is done by online upto 47%

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

not_cancelled_data = hotel_data[hotel_data['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace = True)

plt.figure(figsize = (20,6))
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label = 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label = 'cancelled')
plt.legend()
plt.show()

# %% [markdown]
# As seen in the graph, reservation are canceled when the ADR is higher than when it is not canceled.So this prove that higher the prices leads to higher cancellation

# %% [markdown]
# ## Suggestions

# %% [markdown]
# Cancellation rates rise as the price does. In order to prevent cancellation of reservation, hotel could work on their pricing strategies and try to lower the rates for specifc hotle and locations. They can provide some discounts to the consumers.

# %% [markdown]
# As the ratio of cancellation and not cancellation of the resort hotel is higher in the resort hotel than the city hotel. So the hotles should provide a reasonable discount on the room prices on weekends or hoilydays.

# %% [markdown]
# In the month of January, hotel can start campaigns or marketing with a reasonable amount to increse their revenue as the cancellation is the highest in this month.

# %% [markdown]
# They can also increase there hotel quality and servies mainly in the Portugal to reduce the cancellation rate.
